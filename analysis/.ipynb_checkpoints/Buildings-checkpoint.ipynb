# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime, calendar, time
# %matplotlib inline

# %% [markdown]
# Read in the buildings file

# %%
header = ['id','user','version','minVersion','validSince','validUntil','name']
buildings = pd.read_csv('../util/buildings.data',names=header, sep='\t')

# %% [markdown]
# Calculate new columns and convert to Python objects

# %%
buildings['date'] = buildings.validSince.apply(lambda x: pd.Timestamp(x*1000000000).date())
buildings.replace("false", np.NaN, inplace=True)
buildings.validUntil = buildings['validUntil'].astype(float)

# %%
buildings.id.count(), buildings.id.nunique(), buildings.user.nunique(), buildings.query('version==1').id.count()
# Out:
# (65686, 55720, 374, 57173)

# %% [markdown]
# Set all `validUntil` dates to today

# %% [raw]
# TIME_NOW = calendar.timegm(time.gmtime())
# buildings.validUntil.replace(np.NaN, TIME_NOW, inplace=True)
# buildings.validUntil = buildings.validUntil.astype(int)
# buildings['lifespan'] = buildings.apply(lambda r: r.validUntil - r.validSince, axis=1)

# %% [markdown]
# Look at what we're working with

# %%
buildings.head(1)
# Out:
#           id          user  version  minVersion  validSince  validUntil  name  \
# 0  323369513  DougPeterson        1         0.0  1421808809         NaN   NaN
#
#          date
# 0  2015-01-21

# %%
buildings.dtypes
# Out:
# id              int64
# user           object
# version         int64
# minVersion    float64
# validSince      int64
# validUntil    float64
# name          float64
# date           object
# dtype: object

# %%
buildings.head(3)
# Out:
#           id          user  version  minVersion  validSince  validUntil  name  \
# 0  323369513  DougPeterson        1         0.0  1421808809         NaN   NaN
# 1  323369491  DougPeterson        1         0.0  1421808808         NaN   NaN
# 2  259294439  DougPeterson        1         0.0  1391226175         NaN   NaN
#
#          date
# 0  2015-01-21
# 1  2015-01-21
# 2  2014-02-01

# %%
latest_versions = buildings.query("validUntil=={0}".format(TIME_NOW))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5d838e52dfd4> in <module>()
# ----> 1 latest_versions = buildings.query("validUntil=={0}".format(TIME_NOW))
#
# NameError: name 'TIME_NOW' is not defined

# %%
sns.set_style("dark")
ax = plt.figure(num=None, figsize=(10, 2), dpi=95)
buildings.height.hist(bins=20)
fig = plt.gcf()
fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-444-cb0d8a0ac69c> in <module>()
#       1 sns.set_style("dark")
#       2 ax = plt.figure(num=None, figsize=(10, 2), dpi=95)
# ----> 3 buildings.height.hist(bins=20)
#       4 fig = plt.gcf()
#       5 fig.autofmt_xdate()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'height'

# %% [markdown]
# When were buildings created in Detroit?

# %%
gb_dates = buildings.query('version==1').groupby('date').aggregate({'id':pd.Series.count, 'user': pd.Series.nunique})

# %%
sns.set_style("darkgrid"); axes = []
axes.append( gb_dates.id.cumsum().rolling(window=30).mean().plot(figsize=(10,5)) )
axes.append( gb_dates.user.cumsum().rolling(window=30).mean().plot(figsize=(10,5), color='orange', ax=axes[0].twinx()) )
lines, labels = axes[0].get_legend_handles_labels()
for ax in axes[1:]:
    line, label = ax.get_legend_handles_labels()
    lines += line
axes[-1].legend(lines, ['Building Edits','Users'], loc=0, fontsize=18);
axes[0].set_ylabel('Building Count (to date)');
axes[1].set_ylabel('User Count (to date)');

# %% [markdown]
# What about the latest edits to buildings?

# %%
gb_dates = latest_versions.groupby('date').aggregate({'id':pd.Series.count, 'user': pd.Series.nunique})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-71354dcf03f9> in <module>()
# ----> 1 gb_dates = latest_versions.groupby('date').aggregate({'id':pd.Series.count, 'user': pd.Series.nunique})
#
# NameError: name 'latest_versions' is not defined

# %%
sns.set_style("darkgrid"); axes = []
axes.append( gb_dates.id.cumsum().rolling(window=30).mean().plot(figsize=(10,5)) )
axes.append( gb_dates.user.cumsum().rolling(window=30).mean().plot(figsize=(10,5), color='orange', ax=axes[0].twinx()) )
lines, labels = axes[0].get_legend_handles_labels()
for ax in axes[1:]:
    line, label = ax.get_legend_handles_labels()
    lines += line
axes[-1].legend(lines, ['Building Edits','Users'], loc=0, fontsize=18);
axes[0].set_ylabel('Building Count (to date)');
axes[1].set_ylabel('User Count (to date)');

# %% [markdown]
# How long between building edits?

# %%
buildings.lifespan.hist()

# %% [markdown]
# # Learning about Names

# %%
buildings_gb_date = buildings[buildings.name.notnull()].groupby('date')

# %%
ax = buildings_gb_date.aggregate({'id':'nunique'}).cumsum().plot()
ax.legend(['When names were added in detroit'])

# %%
gb_dates = buildings.groupby('date').aggregate({'id':pd.Series.count, 'user': pd.Series.nunique, 'name':'count'})

# %%
sns.set_style("darkgrid"); axes = []
axes.append( gb_dates.id.cumsum().rolling(window=7).mean().plot(figsize=(10,5)) )
axes.append( gb_dates.user.cumsum().rolling(window=7).mean().plot(figsize=(10,5), color='orange', ax=axes[0].twinx()) )
lines, labels = axes[0].get_legend_handles_labels()
for ax in axes[1:]:
    line, label = ax.get_legend_handles_labels()
    lines += line
axes[-1].legend(lines, ['Building Edits','Users'], loc=0, fontsize=18);
axes[0].set_ylabel('Building Count (to date)');
axes[1].set_ylabel('User Count (to date)');

# %%
sns.set_style("darkgrid"); axes = []
axes.append( gb_dates.id.cumsum().rolling(window=7).mean().plot(figsize=(10,5)) )
axes.append( gb_dates.name.cumsum().rolling(window=7).mean().plot(figsize=(10,5), color='orange', ax=axes[0].twinx()) )
lines, labels = axes[0].get_legend_handles_labels()
for ax in axes[1:]:
    line, label = ax.get_legend_handles_labels()
    lines += line
axes[-1].legend(lines, ['Building Edits','Names'], loc=0, fontsize=18);
axes[0].set_ylabel('Building Count (to date)');
axes[1].set_ylabel('Names Count (to date)');

# %%
buildings.groupby('user').aggregate({'id':'nunique','version':'count','validSince':min,'validUntil':max}).sort_values(by='id',ascending=False)
# Out:
#                                    id  version  validSince    validUntil
# user
# markscalf                       20531    20606  1446843543  1.533475e+09
# Aibara                          16344    16522  1389833180  1.534213e+09
# PeterEastern                     2733     2816  1273095091  1.534213e+09
# leppekmi                         1943     3232  1424833276  1.523029e+09
# Tyson Gersh                      1939     2045  1386142203  1.532607e+09
# MintCondition                    1753     1755  1464982408  1.533475e+09
# DougPeterson                     1505     1629  1370490729  1.532795e+09
# dexterslu                        1348     1423  1420646397  1.533057e+09
# maxerickson                      1275     1302  1374587275  1.532094e+09
# MichaelGSmith                    1053     1473  1297214436  1.532087e+09
# Stevedawg313                      869      872  1512117468  1.531947e+09
# IanH                              794      900  1480709752  1.533055e+09
# EvGill                            714      716  1525876900  1.533227e+09
# nopyet                            614      647  1403206737  1.530890e+09
# freebeer                          601      601  1473157081  1.532960e+09
# AaronAsAChimp                     468      630  1350747940  1.531324e+09
# matt hampel                       401      440  1266248927  1.531956e+09
# andrewpmk                         376      386  1237812145  1.530814e+09
# lmum                              363      391  1477364381  1.534213e+09
# ArtDoes                           284      293  1496969521  1.527250e+09
# YvettevdV                         277      281  1421165231  1.484487e+09
# Skybunny                          261      280  1402803150  1.530315e+09
# matteditmsts                      245      293  1260833552  1.529492e+09
# jmcbroom                          239      252  1379795010  1.532461e+09
# JessAk71                          231      237  1485413040  1.534214e+09
# mapper175                         195      229  1383781061  1.533210e+09
# marianp_telenav                   190      197  1494834960  1.531396e+09
# Delocuro                          173      211  1512191106  1.532087e+09
# YalCat                            144      144  1438795150  1.494026e+09
# a_white                           123      155  1335208224  1.530541e+09
# ...                               ...      ...         ...           ...
# jerryindetroit                      1        1  1424823724  1.443846e+09
# jgrant313                           1        1  1512130403           NaN
# kisaa                               1        1  1432380222  1.523029e+09
# kweikal                             1        1  1280872283  1.402974e+09
# littlejk1                           1        1  1533960202           NaN
# b3rogers                            1        1  1369596090  1.462761e+09
# aadams13                            1        1  1483570131           NaN
# PhilR8                              1        2  1350572472  1.499616e+09
# Sanjak                              1        1  1392066337  1.499612e+09
# Prof Eric Cameron                   1        1  1486008703  1.506242e+09
# PropertyVIEW®                       1        2  1497641960  1.521124e+09
# Rexma423                            1        1  1522275909           NaN
# RocketMan                           1        1  1399124890  1.415938e+09
# Roro86h                             1        1  1516225474           NaN
# RoziB                               1        1  1361393314  1.517512e+09
# SLORENC                             1        1  1465309799  1.468627e+09
# SafiG7                              1        1  1517878580           NaN
# Sammy Herninko                      1        1  1526331595           NaN
# Sbarnes                             1        1  1479437062  1.484924e+09
# 25or6to4                            1        1  1490853884           NaN
# Shannon3                            1        1  1386546014  1.448760e+09
# StackKorora                         1        1  1534018399           NaN
# Steven Deeds                        1        1  1465079212  1.495793e+09
# StuntManSam                         1        1  1489412091  1.517106e+09
# Sundance                            1        1  1378502443  1.411148e+09
# The Henry Autograph Collection      1        2  1454057779  1.476900e+09
# TorhamZed                           1        1  1374443829           NaN
# Walter Schlögl                      1        1  1420118602  1.480269e+09
# WestleyM                            1        1  1483814148           NaN
# Yoshinion                           1        1  1442165763  1.462819e+09
#
# [374 rows x 4 columns]

# %% [markdown]
# # User Editing Network?

# %%
import networkx as nx

# %%
G = nx.DiGraph()
for line in open('../util/users.edgelist','r'):
    sourceLabel, targetLabel, weight = line.split(",")
    weight = int(weight)
    if weight > 5:
        G.add_edge(sourceLabel, targetLabel, weight=weight)

# %%
nx.draw_spring(G, with_labels=True)

# %%
nx.write_graphml(G,'/data/www/jennings/detroit_users.graphml')
